# %% [markdown]
# ### Data analysis

# %%
import torch
import torchvision
import torch.nn as nn
import torchvision.transforms as transforms
import pandas as pd
import numpy as np
import torch.nn.functional as F
import os
from matplotlib import pyplot as plt

# %%
TRAIN_PATH = "./data/train/"
device = torch.device("cuda")
transform = transforms.Compose(
    [transforms.ToTensor(),
    #  transforms.CenterCrop(16),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.ImageFolder(TRAIN_PATH, transform=transform)
batch_size = 32
num_workers = 8
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=num_workers)

classes = list(os.listdir(TRAIN_PATH))

# %%
plt.figure(figsize = (20,10))

# get some random training images
images, labels = next(iter(trainloader))

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# show images
imshow(torchvision.utils.make_grid(images))
idx_to_class = {value: key for key, value in trainset.class_to_idx.items()}

print(' '.join('%5s' % idx_to_class[int(label)] for label in list(labels)))
# Out:
# hammer   saw   egg gauge tomato gauge  frog   cat   saw  nest  nest memorial flower flower bacteria bread elephant spider tomato echinoderm monkey snake motor kangaroo antenna   egg carbon bacteria spoon snake   tea bacteria

# %%
images[0:1].size()
# Out:
# torch.Size([1, 3, 64, 64])
